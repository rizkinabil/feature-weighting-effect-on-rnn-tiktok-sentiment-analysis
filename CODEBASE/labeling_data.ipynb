# %% [markdown]
# ## Labelling data

# %%
import pandas as pd
import random

#read dataset
df_tiktok = pd.read_csv('D:\kuliah\THE ONLY TA THINGS\DATA\data not proccessed\data_tiktok_20000.csv')
df_tiktok.head()
# Out:
#                                reviewId               userName  \
# 0  3d053115-7a79-4454-a666-cf93b04a917f             Tania Nita
# 1  6283eec6-f369-4a21-afc4-33d7c060cac0           amas mastria
# 2  4c2bc738-bd22-4b36-89d3-58de02560862      Faishal Muntashir
# 3  7a4b48eb-50d9-4074-8455-a04742e81b6b  Tiara Nuramelia Putri
# 4  65e4b309-890a-494a-8137-49134721c7db          Lia Wijayanti
#
#                                                                                  userImage  \
# 0    https://play-lh.googleusercontent.com/a-/ACB-R5QYwTT5GU9exT1MneOqpow1U00SuPvJQGopjhB-
# 1  https://play-lh.googleusercontent.com/a/AGNmyxYk5RKCADUBSY7JW75ctljeuiiEixRalaXVVUzu=mo
# 2  https://play-lh.googleusercontent.com/a/AGNmyxaKs04CsIsJeirVkpWnsqL95Enr5lVKgm0eapjP=mo
# 3  https://play-lh.googleusercontent.com/a/AGNmyxYi-3laIq8wwZHL2VlPOPIpg14hDeBxki7mnv8Q=mo
# 4  https://play-lh.googleusercontent.com/a/AGNmyxZKrIGotggiQQEZtBdYUfHRZ_7h9Uohe9oJX7jb=mo
#
# ...

# %%
df_tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              20000 non-null  object
#  1   userName              20000 non-null  object
#  2   userImage             20000 non-null  object
#  3   content               20000 non-null  object
#  4   score                 20000 non-null  int64
#  5   thumbsUpCount         20000 non-null  int64
#  6   reviewCreatedVersion  12557 non-null  object
#  7   at                    20000 non-null  object
#  8   replyContent          536 non-null    object
#  9   repliedAt             536 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 1.5+ MB

# %%
#Analyze total score review
df_tiktok['score'].value_counts()
# Out:
# 5    14589
# 1     2319
# 4     1554
# 3      911
# 2      627
# Name: score, dtype: int64

# %%
# get the number of missing data points per column
missing_values_count = df_tiktok.isnull().sum()
missing_values_count
# Out:
# reviewId                    0
# userName                    0
# userImage                   0
# content                     0
# score                       0
# thumbsUpCount               0
# reviewCreatedVersion     7443
# at                          0
# replyContent            19464
# repliedAt               19464
# dtype: int64

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
display(df_tiktok.loc[0:75,['content', 'score']])
# Out:
#                                                                                                                               content  \
# 0                                                                                                                               Bagus
# 1                                        saya beri bintang 5 jika tiktok saya kembali app ny ad di play store di luar PlayStore gaada
# 2                                                                                                                      Sangat berguna
# 3                                                                                                             Apknya bagus banget 😍😍😍
# 4                            Wah aku udah punya temen di tiktok tapi aku males soal nya di tik tok banyak yang sesat di video tik tok
# ..                                                                                                                                ...
# ...

# %%
df_tiktok[["content", "score"]]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     content  \
# ...

# %%
# convert data type
# df_tiktok['score'] = df_tiktok['score'].astype('int')

# %%
# numeric value


def label_score(score):
    return -1 if score <= 2 else \
           0 if score == 3 else 1

X = [x for x in df_tiktok.content]
Y = [label_score(score) for score in df_tiktok.score]

label = []
for x in df_tiktok.score:
    label = Y

# print(label)
print(f"sample of labeled data")
print(f"{Y[9]}: {X[9][0:100]}...")
print(f"{Y[9]}: {X[9][0:100]} ...")
# Out:
# sample of labeled data
# 1: Oke lah...
# 1: Oke lah ...

# %%
# # non-numeric value

# def label_score(score):
#     return "negative" if score <= 2 else \
#            "netral" if score == 3 else "positif"

# X = [x for x in df_tiktok.content]
# Y = [label_score(score) for score in df_tiktok.score]

# label = []
# for x in df_tiktok.score:
#     label = Y

# # print(label)
# print(f"sample of labeled data")
# print(f"{Y[10]}: {X[10][0:100]}...")
# print(f"{Y[920]}: {X[920][0:100]} ...")

# %%
df_tiktok['label'] = label
df_tiktok
# Out:
#                                    reviewId               userName  \
# 0      3d053115-7a79-4454-a666-cf93b04a917f             Tania Nita
# 1      6283eec6-f369-4a21-afc4-33d7c060cac0           amas mastria
# 2      4c2bc738-bd22-4b36-89d3-58de02560862      Faishal Muntashir
# 3      7a4b48eb-50d9-4074-8455-a04742e81b6b  Tiara Nuramelia Putri
# 4      65e4b309-890a-494a-8137-49134721c7db          Lia Wijayanti
# ...                                     ...                    ...
# 19995  2fdd0fe5-4ba1-471e-b1af-3034c1b254cc             vivo Tawar
# 19996  2374f025-c94f-40f9-bdf4-b8e8c8b23ca0             Fatma Wati
# 19997  63319dec-5dfd-437f-af00-c1dc26e7aeff     Nayna Naynamikaila
# 19998  1bfb37e6-e208-45ee-851e-0fc5f3c97539         irfan setiawan
# 19999  b9fbf47a-c9ed-4086-9b55-a88ef2ce5bd1        Khoirul Maulana
#
#                                                                                      userImage  \
# ...

# %%
sampel_labeling_20000 = df_tiktok.sample(n=20000, replace=True)

# %%
sampel_labeling_20000
# Out:
#                                    reviewId               userName  \
# 13212  f835c391-1785-4e7a-94fd-b7fbf8dab2cf         Rahman Ramdani
# 11968  692b5377-d9a3-4ccc-914c-cd6a4a60ae6e            Aser Pigome
# 8454   cad26a3d-503b-44d2-8fea-c0b4e9acda34             Nie Nurani
# 4929   5423737e-f478-4822-a0ab-890164ec2464             Alphantino
# 10995  28b927b2-be8a-4d3a-bd73-a7599ffb82a2          Guruh Ciptadi
# ...                                     ...                    ...
# 17860  56d5b962-6e92-488b-af3e-48a522ce8c31    GendisAufa Maisarah
# 2711   61bbab55-2903-4ef8-9425-4871dc1fc78e               _Slxmaa_
# 18604  9082a70a-ec9b-4139-b4b0-f36c9e0aebd1            ahmad fauzi
# 2888   0f6444ca-7215-4d19-b2cb-4ee15604014e          Anindya Rahma
# 17381  fc72024a-6868-4c4f-8cbe-61117957b984  Ari kurniawan Saputra
#
#                                                                                      userImage  \
# ...

# %%
sampel_labeling_20000.to_csv(r'D:\kuliah\THE ONLY TA THINGS\DATA\data not proccessed\data_tiktok_20000.csv', index=False, header=True)

# %% [markdown]
# ## Labelling data

# %%
import pandas as pd
import random

#read dataset
df_tiktok = pd.read_csv('D:\kuliah\THE ONLY TA THINGS\DATA\data not proccessed\data_tiktok_tambah_5000.csv')
df_tiktok.head()
# Out:
#                                reviewId             userName
# 0  dd6d4271-8caf-49ca-9e1c-31439cd1019c          Celsi Usman  \
# 1  e6ce3722-36fa-40d5-928f-e9c68acbf97b  ZAHRA ZALIKA CHANEL
# 2  81169eaf-600c-4ac3-9c50-4dcee6cb9b7e           Salsa Bila
# 3  fa78b797-b50f-43f9-909d-8931363d9e0c        Caca Ponorogo
# 4  e7d87782-d860-4575-a0b7-c57730950661             Alu Card
#
#                                            userImage
# 0  https://play-lh.googleusercontent.com/a/AGNmyx...  \
# 1  https://play-lh.googleusercontent.com/a-/ACB-R...
# 2  https://play-lh.googleusercontent.com/a/AGNmyx...
# 3  https://play-lh.googleusercontent.com/a/AGNmyx...
# 4  https://play-lh.googleusercontent.com/a/AGNmyx...
#
#                                              content  score  thumbsUpCount
# 0                           Gak bisa download tiktok      1              0  \
# 1  mengapa tiktok tidak memperbolehkan anak kecil...      1              0
# 2                            Gak bisa bisa di donlod      1              0
# 3                 Tuto fyp. Opo i apk Ra ISO fyp e 🪨      1              0
# 4    Nangis banget baru buka tiktok eh akun hilang 😭      1              0
#
#   reviewCreatedVersion                   at replyContent repliedAt appVersion
# 0                  NaN  2023-05-21 10:56:26          NaN       NaN        NaN
# 1               29.5.5  2023-05-21 10:54:03          NaN       NaN     29.5.5
# 2                  NaN  2023-05-21 10:47:40          NaN       NaN        NaN
# 3               29.6.4  2023-05-21 10:44:11          NaN       NaN     29.6.4
# 4                  NaN  2023-05-21 10:43:34          NaN       NaN        NaN

# %%
df_tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              5000 non-null   object
#  1   userName              5000 non-null   object
#  2   userImage             5000 non-null   object
#  3   content               5000 non-null   object
#  4   score                 5000 non-null   int64
#  5   thumbsUpCount         5000 non-null   int64
#  6   reviewCreatedVersion  3146 non-null   object
#  7   at                    5000 non-null   object
#  8   replyContent          73 non-null     object
#  9   repliedAt             73 non-null     object
#  10  appVersion            3146 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 429.8+ KB

# %%
#Analyze total score review
df_tiktok['score'].value_counts()
# Out:
# score
# 1    1000
# 2    1000
# 3    1000
# 4    1000
# 5    1000
# Name: count, dtype: int64

# %%
# get the number of missing data points per column
missing_values_count = df_tiktok.isnull().sum()
missing_values_count
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1854
# at                         0
# replyContent            4927
# repliedAt               4927
# appVersion              1854
# dtype: int64

# %%
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
display(df_tiktok.loc[0:75,['content', 'score']])
# Out:
#                                                                                                                                                                      content
# 0                                                                                                                                                   Gak bisa download tiktok  \
# 1   mengapa tiktok tidak memperbolehkan anak kecil untuk memainkannya kan ini untuk menghibur akun saya telah di blokir oleh Tiktok 5 kali dan saya sangat tidak senang 😡😡😠😡
# 2                                                                                                                                                    Gak bisa bisa di donlod
# 3                                                                                                                                         Tuto fyp. Opo i apk Ra ISO fyp e 🪨
# 4                                                                                                                            Nangis banget baru buka tiktok eh akun hilang 😭
# ..                                                                                                                                                                       ...
# 71                                                                                                                                                         Konco kamar mandi
# 72                                                                                                                                           fyp vidio saya semua luar negri
# 73                                                                                                                                                         Taaiiiiiii sampah
# 74                                                                                                                                                      Sangat nyamamapk ini
# 75                                                                                              gak ada vt bokep nya isinya nanggung cuman cwe pake bh sama pamer belahan TT
#
#     score
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 71      1
# 72      1
# 73      1
# 74      1
# 75      1
#
# [76 rows x 2 columns]

# %%
df_tiktok[["content", "score"]]
# Out:
#                                                                                                                                                                        content
# 0                                                                                                                                                     Gak bisa download tiktok  \
# 1     mengapa tiktok tidak memperbolehkan anak kecil untuk memainkannya kan ini untuk menghibur akun saya telah di blokir oleh Tiktok 5 kali dan saya sangat tidak senang 😡😡😠😡
# 2                                                                                                                                                      Gak bisa bisa di donlod
# 3                                                                                                                                           Tuto fyp. Opo i apk Ra ISO fyp e 🪨
# 4                                                                                                                              Nangis banget baru buka tiktok eh akun hilang 😭
# ...                                                                                                                                                                        ...
# 4995                                                                                                                                                        Y Ko susah si bang
# 4996                                                                                                                                                                     🥰🥰🥰🥰🥰
# 4997                                                                                                                                                     Tidak bisa mendownlod
# 4998                                                                                                                             Bagus banget!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 4999                                                     ya allah semoga bisa donlod tiktok aku soalnya beberapa kali ga bisa donlod tiktok semoga sekarang bisa kedonlod amin
#
#       score
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 4995      5
# 4996      5
# 4997      5
# 4998      5
# 4999      5
#
# [5000 rows x 2 columns]

# %%
# convert data type
# df_tiktok['score'] = df_tiktok['score'].astype('int')

# %%
# numeric value


def label_score(score):
    return -1 if score <= 3 else \
           0 if score == 3 else 1

X = [x for x in df_tiktok.content]
Y = [label_score(score) for score in df_tiktok.score]

label = []
for x in df_tiktok.score:
    label = Y

# print(label)
print(f"sample of labeled data")
print(f"{Y[9]}: {X[9][0:100]}...")
print(f"{Y[9]}: {X[9][0:100]} ...")
# Out:
# sample of labeled data
# -1: Share lokasi lah anjir kalau berani lu Tik Tok...
# -1: Share lokasi lah anjir kalau berani lu Tik Tok ...

# %%
# # non-numeric value

# def label_score(score):
#     return "negative" if score <= 2 else \
#            "netral" if score == 3 else "positif"

# X = [x for x in df_tiktok.content]
# Y = [label_score(score) for score in df_tiktok.score]

# label = []
# for x in df_tiktok.score:
#     label = Y

# # print(label)
# print(f"sample of labeled data")
# print(f"{Y[10]}: {X[10][0:100]}...")
# print(f"{Y[920]}: {X[920][0:100]} ...")

# %%
df_tiktok['label'] = label
df_tiktok
# Out:
#                                   reviewId             userName
# 0     dd6d4271-8caf-49ca-9e1c-31439cd1019c          Celsi Usman  \
# 1     e6ce3722-36fa-40d5-928f-e9c68acbf97b  ZAHRA ZALIKA CHANEL
# 2     81169eaf-600c-4ac3-9c50-4dcee6cb9b7e           Salsa Bila
# 3     fa78b797-b50f-43f9-909d-8931363d9e0c        Caca Ponorogo
# 4     e7d87782-d860-4575-a0b7-c57730950661             Alu Card
# ...                                    ...                  ...
# 4995  27d8aaa2-8b47-4524-80fc-19bf98258238    Asyraf Masih idup
# 4996  137a42a2-13c4-443e-b619-f57e7a9bb93c           Eza Parfum
# 4997  781b3997-ef50-4076-baa8-286017aa80c9      Indri Fatmawati
# 4998  8e19e7bb-9f4e-4b99-b355-f80c5665b3c2  DaanZoqiKun Yiieexz
# 4999  f62f1a0a-e5b6-4067-abef-66a91571b171        Farhan Supyan
#
#                                                                                      userImage
# 0      https://play-lh.googleusercontent.com/a/AGNmyxYMpFrtI5iRRTGL8dzhTT-6J9Ni9Pfmx9c6lA8l=mo  \
# 1      https://play-lh.googleusercontent.com/a-/ACB-R5Txy1i49imah7-CBoECbkAod9yMbPmnuwP2qHAKmQ
# 2      https://play-lh.googleusercontent.com/a/AGNmyxZlCHBRzEJwqU8G7Y6x347RRD5FXsypWrcqI0A4=mo
# 3      https://play-lh.googleusercontent.com/a/AGNmyxaww7NP6A4i5xx52r_nHwHbhAbzxqrYmQNahNap=mo
# 4      https://play-lh.googleusercontent.com/a/AGNmyxYQaebHQiH0dEtzB7Z1VA6COWO5x-q-BeGDqrLt=mo
# ...                                                                                        ...
# 4995   https://play-lh.googleusercontent.com/a-/ACB-R5RcXWVSwfV2zIuXk75WCzdaeMuHcqbNsyUAyVxahg
# 4996  https://play-lh.googleusercontent.com/a-/ACB-R5THszj3_VhWQKU6he_G3M7ACwg7_YA0rpFTuTabfI0
# 4997   https://play-lh.googleusercontent.com/a/AGNmyxZXIIT9Hu1xdAjscfc7blrPYfFC6qYWhAWWbsFj=mo
# 4998   https://play-lh.googleusercontent.com/a/AGNmyxZBRmc9gA1DVEdRPYpbRt_LdNchvg_UOcrlBaYe=mo
# 4999   https://play-lh.googleusercontent.com/a/AGNmyxbdP0IkAtWKDO88VVl9C4Nxds4V_43Zd3thTWjL=mo
#
#                                                                                                                                                                        content
# 0                                                                                                                                                     Gak bisa download tiktok  \
# 1     mengapa tiktok tidak memperbolehkan anak kecil untuk memainkannya kan ini untuk menghibur akun saya telah di blokir oleh Tiktok 5 kali dan saya sangat tidak senang 😡😡😠😡
# 2                                                                                                                                                      Gak bisa bisa di donlod
# 3                                                                                                                                           Tuto fyp. Opo i apk Ra ISO fyp e 🪨
# 4                                                                                                                              Nangis banget baru buka tiktok eh akun hilang 😭
# ...                                                                                                                                                                        ...
# 4995                                                                                                                                                        Y Ko susah si bang
# 4996                                                                                                                                                                     🥰🥰🥰🥰🥰
# 4997                                                                                                                                                     Tidak bisa mendownlod
# 4998                                                                                                                             Bagus banget!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 4999                                                     ya allah semoga bisa donlod tiktok aku soalnya beberapa kali ga bisa donlod tiktok semoga sekarang bisa kedonlod amin
#
#       score  thumbsUpCount reviewCreatedVersion                   at
# 0         1              0                  NaN  2023-05-21 10:56:26  \
# 1         1              0               29.5.5  2023-05-21 10:54:03
# 2         1              0                  NaN  2023-05-21 10:47:40
# 3         1              0               29.6.4  2023-05-21 10:44:11
# 4         1              0                  NaN  2023-05-21 10:43:34
# ...     ...            ...                  ...                  ...
# 4995      5              0                  NaN  2023-05-20 14:56:58
# 4996      5              0               29.5.5  2023-05-20 14:55:58
# 4997      5              0                  NaN  2023-05-20 14:54:42
# 4998      5              0               29.0.3  2023-05-20 14:54:41
# 4999      5              0               26.1.3  2023-05-20 14:52:26
#
#      replyContent repliedAt appVersion  label
# 0             NaN       NaN        NaN     -1
# 1             NaN       NaN     29.5.5     -1
# 2             NaN       NaN        NaN     -1
# 3             NaN       NaN     29.6.4     -1
# 4             NaN       NaN        NaN     -1
# ...           ...       ...        ...    ...
# 4995          NaN       NaN        NaN      1
# 4996          NaN       NaN     29.5.5      1
# 4997          NaN       NaN        NaN      1
# 4998          NaN       NaN     29.0.3      1
# 4999          NaN       NaN     26.1.3      1
#
# [5000 rows x 12 columns]

# %%
sampel_labeling = df_tiktok.sample(n=5000, replace=True)

# %%
sampel_labeling
# Out:
#                                   reviewId                   userName
# 1853  f9753a2e-bd28-4b05-b95b-62c22b905fd4             Yeni Oktaviani  \
# 3119  4dd3c161-e9d7-44de-b4c0-f5589ff97416  faotdorkas82 dorkasfaot82
# 455   6dfacd5f-3bda-437b-a20d-71a4b7344558               Joko Santosa
# 4453  0eef1271-cabb-406e-ae08-ad4a0cbd6c63              Adil nih Boss
# 2243  e78eafd1-2d10-4b9a-b325-3b5994fca72a            Pengguna Google
# ...                                    ...                        ...
# 1134  896c13bd-4bdb-4821-a20b-54a7a66d4dbd              Davino Alexis
# 1627  46e728f9-b3dc-48f5-ab81-bbb0c49b9623           Amina Musdalifah
# 3106  58f6ea26-4281-4e30-9852-dda0a70d6182                  Cika Line
# 4707  8871b829-9078-4fda-a568-03c8bbca0af5         Adriansyah MC BALI
# 4963  6571e1cb-51c0-476d-9262-9ababe82c4f1             heldaria anita
#
#                                                                                                                      userImage
# 1853                                   https://play-lh.googleusercontent.com/a/AGNmyxaOBrPJMNJx09Z6U7890OnYeOQCchubpfIFjD_Z=mo  \
# 3119                                     https://play-lh.googleusercontent.com/a-/ACB-R5TcJpbn-ZErmSGAOJW4Gj3hy5BnKQSb_Q4fabgl
# 455                                    https://play-lh.googleusercontent.com/a/AGNmyxYJGSP8KHFEZMWRsKpghJey1dp_62YLgsIzFQ7S=mo
# 4453                                   https://play-lh.googleusercontent.com/a/AGNmyxb9kwDryhX3Lh9QHbc_HGQk9pEKUKf11Ml3DhRE=mo
# 2243  https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g
# ...                                                                                                                        ...
# 1134                                   https://play-lh.googleusercontent.com/a/AGNmyxaf20iEabcwsic5r6XJnyuYBgSupc-ZpcFnGGkf=mo
# 1627                                     https://play-lh.googleusercontent.com/a-/ACB-R5STNXMuJKIkUhMmqtk7oglNZRWxzIOXceYW3FYg
# 3106                                     https://play-lh.googleusercontent.com/a-/ACB-R5QV0dpJA-jH1iuVHP3lYyMEb4CzEvgOQxU3wNIf
# 4707                                   https://play-lh.googleusercontent.com/a-/ACB-R5RB35VcKMfrjKitayprU6lxlJGCwSwu1fMyiQwC9w
# 4963                                   https://play-lh.googleusercontent.com/a/AGNmyxYzK6JAb52r0OEImBQ7OHkPlVO2C0Qh8wMxmASm=mo
#
#                                                                                                                                                                                                                              content
# 1853                                                                                                                                                                           Buruk banget suka keluar sendiri dari aplikasi nya...  \
# 3119                                                                                                                                                 Bagus ini bagus banget aku suka aku senang bisa download apk video pendek gini🤩
# 455                                                                                                                             Tolong pihak tik tok masa dikit dikit di akun gw di blokir mana pake akun lainnya gk bisa,emang babi
# 4453                                                                                                                TIKTOK saya ingin fyp. tapi susah Tolong masuk kan video saya ke beranda TIKTOK , Ini nama TIKTOK saya.adilskj10
# 2243                                                                                                                                                                                            Udah tiga tahun segitu aja yg nonton
# ...                                                                                                                                                                                                                              ...
# 1134                                                                                                                                                                                                                      l all kp00
# 1627                                                                                                                                                                                                                            😎😎😎😎
# 3106  Hai menurut ku aplikasi ya bagus cuman orang orang kadang kadang video aneh-aneh dan ada yang toxic ada video yang ada orang ada salah dikit langsung di hujat jadi mohon yang pake Tik tok buat menjadi yang lebih baik lagi!
# 4707                                                                                                                                                                                                                           Keren
# 4963                                                                                                                                                                                                          bagus sekali,saya suka
#
#       score  thumbsUpCount reviewCreatedVersion                   at
# 1853      2              0               28.8.3  2023-05-05 14:58:27  \
# 3119      4              0                  NaN  2023-05-20 15:05:45
# 455       1              0               28.6.5  2023-05-18 23:53:18
# 4453      5              0               29.3.4  2023-05-20 22:14:56
# 2243      3              0               29.6.2  2023-05-18 15:46:19
# ...     ...            ...                  ...                  ...
# 1134      2              0               29.2.4  2023-05-18 16:08:20
# 1627      2              0               29.3.4  2023-05-10 16:14:45
# 3106      4              0               29.6.4  2023-05-20 17:09:23
# 4707      5              0               29.5.5  2023-05-20 19:17:08
# 4963      5              0               29.2.4  2023-05-20 15:35:31
#
#      replyContent repliedAt appVersion  label
# 1853          NaN       NaN     28.8.3     -1
# 3119          NaN       NaN        NaN      1
# 455           NaN       NaN     28.6.5     -1
# 4453          NaN       NaN     29.3.4      1
# 2243          NaN       NaN     29.6.2     -1
# ...           ...       ...        ...    ...
# 1134          NaN       NaN     29.2.4     -1
# 1627          NaN       NaN     29.3.4     -1
# 3106          NaN       NaN     29.6.4      1
# 4707          NaN       NaN     29.5.5      1
# 4963          NaN       NaN     29.2.4      1
#
# [5000 rows x 12 columns]

# %%
sampel_labeling.to_csv(r'D:\kuliah\THE ONLY TA THINGS\DATA\data not proccessed\data_tiktok_5000_tambahan.csv', index=False, header=True)

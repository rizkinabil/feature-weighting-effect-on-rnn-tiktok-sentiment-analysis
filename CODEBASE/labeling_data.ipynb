# %% [markdown]
# ## Labelling data

# %%
import pandas as pd
import random

#read dataset
df_tiktok = pd.read_csv('D:\kuliah\THE ONLY TA THINGS\DATA\data_review_tiktok_3000.csv')
df_tiktok.head()
# Out:
#                                reviewId                      userName  \
# 0  19d1c341-ca7d-4b53-8948-207bb6c1b1fa  Desak Putu Suci Purnama Sari
# 1  ea498e0c-ed05-4edd-b3db-46899cf708b2                  khalif Akbar
# 2  d47a2203-298b-4782-9932-57cacd52ff9f                   It's Wowici
# 3  498c93e1-3c6a-4ae3-913d-586b09ba8be9                     Nani Miot
# 4  7d91e803-2285-40dd-a5ba-baf93094bb15                   Darel Saleh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AEdFTp...
# 1  https://play-lh.googleusercontent.com/a/AEdFTp...
# 2  https://play-lh.googleusercontent.com/a-/AD5-W...
# 3  https://play-lh.googleusercontent.com/a/AEdFTp...
# 4  https://play-lh.googleusercontent.com/a/AEdFTp...
#
#                                              content  score  thumbsUpCount  \
# 0   BAGUSSS OH YA TIKTOK KASI AKU CENTANG BIRU DONKK      5              0
# ...

# %%
df_tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              3000 non-null   object
#  1   userName              3000 non-null   object
#  2   userImage             3000 non-null   object
#  3   content               3000 non-null   object
#  4   score                 3000 non-null   int64
#  5   thumbsUpCount         3000 non-null   int64
#  6   reviewCreatedVersion  1826 non-null   object
#  7   at                    3000 non-null   object
#  8   replyContent          0 non-null      float64
#  9   repliedAt             0 non-null      float64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 234.5+ KB

# %%
#Analyze total score review
df_tiktok['score'].value_counts()
# Out:
# 5    1920
# 1     572
# 4     212
# 3     166
# 2     130
# Name: score, dtype: int64

# %%
# get the number of missing data points per column
missing_values_count = df_tiktok.isnull().sum()
missing_values_count
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1174
# at                         0
# replyContent            3000
# repliedAt               3000
# dtype: int64

# %%
df_tiktok.head()[["content", "score"]]
# Out:
#                                              content  score
# 0   BAGUSSS OH YA TIKTOK KASI AKU CENTANG BIRU DONKK      5
# 1                                               bgus      5
# 2  Fitur search filternya ilang di hpku, padahal ...      3
# 3                                            👍👍👍👍👍👍👍      5
# 4              Filter terbaru tidak bisa di temukan😢      1

# %%
# convert data type
# df_tiktok['score'] = df_tiktok['score'].astype('int')

# %%
def label_score(score):
    return -1.0 if score <= 2 else \
           0.0 if score == 3 else 1.0

X = [x for x in df_tiktok.content]
Y = [label_score(score) for score in df_tiktok.score]

label = []
for x in df_tiktok.score:
    label = Y

# print(label)
print(f"sample of labeled data")
print(f"{Y[10]}: {X[10][0:100]}...")
print(f"{Y[920]}: {X[920][0:100]} ...")
# Out:
# sample of labeled data
# 1.0: Aplikasi ini sangat bagus sekali. Tapi sering ngelag tolong diperbaiki lagi ya Terima kasih 🙏🙏...
# 0.0: 2kt Paramex 4ls Bodrex 2ls Bodrexin 1kt B.flu 1kt Migra 1kt B. Extra 2kt Ultraflu 1kt Mixagrip 1ls K ...

# %%
df_tiktok['label'] = label
df_tiktok.head()
# Out:
#                                reviewId                      userName  \
# 0  19d1c341-ca7d-4b53-8948-207bb6c1b1fa  Desak Putu Suci Purnama Sari
# 1  ea498e0c-ed05-4edd-b3db-46899cf708b2                  khalif Akbar
# 2  d47a2203-298b-4782-9932-57cacd52ff9f                   It's Wowici
# 3  498c93e1-3c6a-4ae3-913d-586b09ba8be9                     Nani Miot
# 4  7d91e803-2285-40dd-a5ba-baf93094bb15                   Darel Saleh
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AEdFTp...
# 1  https://play-lh.googleusercontent.com/a/AEdFTp...
# 2  https://play-lh.googleusercontent.com/a-/AD5-W...
# 3  https://play-lh.googleusercontent.com/a/AEdFTp...
# 4  https://play-lh.googleusercontent.com/a/AEdFTp...
#
#                                              content  score  thumbsUpCount  \
# 0   BAGUSSS OH YA TIKTOK KASI AKU CENTANG BIRU DONKK      5              0
# ...

# %% [markdown]
# # Sample labeling untuk validasi, data yang diambil sebanyak 30 data

# %%
sampel_labeling_300 = df_tiktok.sample(n=300, replace=True)

# %%
sampel_labeling_300
# Out:
#                                   reviewId                   userName  \
# 2600  c3c5f69d-4b8e-4237-919e-6992d60b9f29                     M ryan
# 2173  82362c4d-4610-47d7-a883-48152da9bf2b      safarar021 safarar021
# 1713  b4a72046-80d6-485a-8187-2945e38d9cc8            norman mahendra
# 2278  4dc9c809-21bb-4370-94d3-d4e83c813be2      dimas riski kurniawan
# 2736  d3ba443c-da1d-4583-8b08-f34180c7f598              bapak sutiman
# ...                                    ...                        ...
# 1710  505e560e-8cee-4cb6-94c4-da3b250ce6e9                      Mi Ki
# 1783  33b9cbce-4eab-42cf-9434-1b429e4c183b  Salsabilla diva ramadhani
# 1967  78a6b622-73ac-46bb-8bc7-e714b856e3bf      Randika Wahyu Anggara
# 614   afde4015-7c1e-4f83-bcb5-ff6cd824270f               Fira Shafira
# 228   dbae0052-8b4f-4737-83ac-0456c18a68a8               fahira jauza
#
#                                               userImage  \
# 2600  https://play-lh.googleusercontent.com/a/AEdFTp...
# ...

# %%
sampel_labeling_300.to_csv(r'D:\kuliah\THE ONLY TA THINGS\DATA\sample_label_300.csv', index=False, header=True)

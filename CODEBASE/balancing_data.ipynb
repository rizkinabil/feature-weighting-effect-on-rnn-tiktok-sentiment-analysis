# %%
import pandas as pd

# %%
data = pd.read_csv('D:\kuliah\THE ONLY TA THINGS\DATA\data clean\cleaned_15000_data_sample.csv')
data.head()
# Out:
#                                              content  score
# 0                                              Keren      5  \
# 1  Woy tiktok menangis gw event mlbb creator base...      5
# 2  Halo disini saya ingin menyampaikan kepada and...      4
# 3  Jangan mau main tiktokla paket kuota cpt hbis ...      2
# 4                    Sangat menghibur asyik dan seru      5
#
#                     at  label
# 0  2023-04-14 19:21:43      1  \
# 1  2023-04-07 23:01:39      1
# 2  2023-04-07 20:13:21      1
# 3  2023-04-11 17:06:47     -1
# 4  2023-04-13 21:08:45      1
#
#                                            cleansing
# 0                                              Keren  \
# 1  Woy tiktok menangis gw event mlbb creator base...
# 2  Halo disini saya ingin menyampaikan kepada and...
# 3  Jangan mau main tiktokla paket kuota cpt hbis ...
# 4                    Sangat menghibur asyik dan seru
#
#                                         case_folding
# ...

# %%
df_negative = data[data.label == -1]
df_negative.info()

# %%
df_neutral = data[data.label == 0]
df_neutral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 354 entries, 11 to 7810
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        354 non-null    object
#  1   score          354 non-null    int64
#  2   at             354 non-null    object
#  3   label          354 non-null    int64
#  4   cleansing      354 non-null    object
#  5   case_folding   354 non-null    object
#  6   no_unwanted    354 non-null    object
#  7   tokenize       354 non-null    object
#  8   normalization  354 non-null    object
#  9   stopwords      354 non-null    object
#  10  stemming       354 non-null    object
#  11  clean          329 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 36.0+ KB

# %%
df_positive = data[data.label == 1]
df_positive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6315 entries, 0 to 7837
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        6315 non-null   object
#  1   score          6315 non-null   int64
#  2   at             6315 non-null   object
#  3   label          6315 non-null   int64
#  4   cleansing      6315 non-null   object
#  5   case_folding   6315 non-null   object
#  6   no_unwanted    6315 non-null   object
#  7   tokenize       6315 non-null   object
#  8   normalization  6315 non-null   object
#  9   stopwords      6315 non-null   object
#  10  stemming       6315 non-null   object
#  11  clean          5738 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 641.4+ KB
